# %% [markdown]
# Module-3 project
# Title :
# Scope of the project :
# Members : Mouyo & VJ
# Data set:
# Stat test:
# Hypothesis:
# Null Hypothesis:
# Assumptions:
# Sales price of homes:factors effecting would be preferred area, numb
# Preferred areas: Good school ratings, low crime rates,

# %%
import pandas as pd

# %%
df_schools = pd.read_csv('/Users/vyju/Documents/Module-3 project/Public_Schools.csv')
df.head()
# Out:
#             X          Y  OBJECTID        NCESID  \
# 0  -73.534274  41.327100         1   90381001361
# 1  -83.002954  42.609035         2  263447007003
# 2 -119.784787  39.509917         3  320048000242
# 3  -98.472562  29.436838         4  483312007184
# 4  -95.491060  29.596903         5  481965001816
#
#                               NAME               ADDRESS              CITY  \
# 0       SCOTTS RIDGE MIDDLE SCHOOL   750 NORTH SALEM RD.        RIDGEFIELD
# 1         BEMIS JUNIOR HIGH SCHOOL      12500 19 MILE RD  STERLING HEIGHTS
# 2  ROGER CORBETT ELEMENTARY SCHOOL  1901 VILLANOVA DRIVE              RENO
# 3            NISD BEXAR COUNTY JJA        1402 HACKBERRY       SAN ANTONIO
# 4                     BRIARGATE EL   15817 BLUE RIDGE RD     MISSOURI CITY
#
#   STATE    ZIP           ZIP4  ... VAL_METHOD                  VAL_DATE  \
# 0    CT   6877  NOT AVAILABLE  ...    IMAGERY  2010-03-05T00:00:00.000Z
# ...

# %%
df_schools1 = df_schools[['NAME', 'CITY', 'STATE', 'ZIP','COUNTY','COUNTYFIPS', 'DISTRICTID']]

# %%
df_schools1.head()
# Out:
#                               NAME              CITY STATE    ZIP     COUNTY  \
# 0       SCOTTS RIDGE MIDDLE SCHOOL        RIDGEFIELD    CT   6877  FAIRFIELD
# 1         BEMIS JUNIOR HIGH SCHOOL  STERLING HEIGHTS    MI  48313     MACOMB
# 2  ROGER CORBETT ELEMENTARY SCHOOL              RENO    NV  89502     WASHOE
# 3            NISD BEXAR COUNTY JJA       SAN ANTONIO    TX  78238      BEXAR
# 4                     BRIARGATE EL     MISSOURI CITY    TX  77489  FORT BEND
#
#    COUNTYFIPS  DISTRICTID
# 0        9001      903810
# 1       26099     2634470
# 2       32031     3200480
# 3       48029     4833120
# 4       48157     4819650

# %%
df_schools_dcmetro = df_schools1.loc[df_schools['STATE'].isin(['VA', 'DC','MD'])]

# %%
df_schools_dcmetro
# Out:
#                               NAME             CITY STATE    ZIP  \
# 300                   PLAZA MIDDLE   VIRGINIA BEACH    VA  23452
# 332              BLAND COUNTY ELEM            BLAND    VA  24315
# 338               FORESTVILLE ELEM      GREAT FALLS    VA  22066
# 353                     ECOFF ELEM          CHESTER    VA  23831
# 356             ALBERT HARRIS ELEM     MARTINSVILLE    VA  24112
# ...                            ...              ...   ...    ...
# 101866      SAMUEL P. LANGLEY ELEM          HAMPTON    VA  23669
# 101908   BERWYN HEIGHTS ELEMENTARY   BERWYN HEIGHTS    MD  20740
# 102158                SALEM MIDDLE   VIRGINIA BEACH    VA  23464
# 102170  EDISON HIGH SCHOOL ACADEMY       ALEXANDRIA    VA  22310
# 102226           BAKER-BUTLER ELEM  CHARLOTTESVILLE    VA  22911
#
#                  COUNTY  COUNTYFIPS  DISTRICTID
# 300      VIRGINIA BEACH       51810     5103840
# 332               BLAND       51021     5100390
# ...

# %%
# Number of Public schools per county
schools_per_county_dcmetro = df_schools_dcmetro['COUNTYFIPS'].value_counts().to_frame()
schools_per_county_dcmetro.reset_index(level=0, inplace=True)
schools_per_county_dcmetro.rename(index=str, columns={"index": "FIPS", "COUNTYFIPS": "NumberOfSchools"}, inplace=True)
schools_per_county_dcmetro.shape
# Out:
# (160, 2)

# %%
df_hospitals = pd.read_csv('/Users/vyju/Documents/Module-3 project/Hospitals.csv')
df.head()
# Out:
#             X          Y  OBJECTID        NCESID  \
# 0  -73.534274  41.327100         1   90381001361
# 1  -83.002954  42.609035         2  263447007003
# 2 -119.784787  39.509917         3  320048000242
# 3  -98.472562  29.436838         4  483312007184
# 4  -95.491060  29.596903         5  481965001816
#
#                               NAME               ADDRESS              CITY  \
# 0       SCOTTS RIDGE MIDDLE SCHOOL   750 NORTH SALEM RD.        RIDGEFIELD
# 1         BEMIS JUNIOR HIGH SCHOOL      12500 19 MILE RD  STERLING HEIGHTS
# 2  ROGER CORBETT ELEMENTARY SCHOOL  1901 VILLANOVA DRIVE              RENO
# 3            NISD BEXAR COUNTY JJA        1402 HACKBERRY       SAN ANTONIO
# 4                     BRIARGATE EL   15817 BLUE RIDGE RD     MISSOURI CITY
#
#   STATE    ZIP           ZIP4  ... VAL_METHOD                  VAL_DATE  \
# 0    CT   6877  NOT AVAILABLE  ...    IMAGERY  2010-03-05T00:00:00.000Z
# ...

# %%
df_hospitals1 = df_hospitals[['NAME', 'CITY', 'STATE', 'ZIP','COUNTY','COUNTYFIPS', 'ST_FIPS']]

# %%
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')

# %%
df_hospitals_dcmetro = df_hospitals1.loc[df_schools['STATE'].isin(['VA', 'DC','MD'])]

# %%
# Number of hospitals per county
hospitals_per_county_dcmetro = df_hospitals_dcmetro['COUNTYFIPS'].value_counts().to_frame()
hospitals_per_county_dcmetro.reset_index(level=0, inplace=True)
hospitals_per_county_dcmetro.rename(index=str, columns={"index": "FIPS", "COUNTYFIPS": "NumberOfHospitals"}, inplace=True)
hospitals_per_county_dcmetro.shape
# Out:
# (220, 2)
